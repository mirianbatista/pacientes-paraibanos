# %%
import pandas as pd

# %%
hosp = pd.read_csv("hosp.csv")
hosp.head()
# Out:
#    COD_MUNICIPIO NO_MUNICIPIO  COD_MUNICIPIO_RES NO_MUNICIPIO_RES     CNES  \
# 0         250010  AGUA BRANCA             240890         PARELHAS  2321777
# 1         250010  AGUA BRANCA             250010      AGUA BRANCA  2321742
# 2         250010  AGUA BRANCA             250010      AGUA BRANCA  2321742
# 3         250010  AGUA BRANCA             250010      AGUA BRANCA  2321742
# 4         250010  AGUA BRANCA             250010      AGUA BRANCA  2321742
#
#                                 ESTABELECIMENTO  COD_PROCEDIMENTO  \
# 0  UNIDADE DE SAUDE DA FAMILIA JOSE GOMES FILHO         301010110
# 1       UNIDADE DE SAUDE DA FAMILIA DE LAGOINHA         301010030
# 2       UNIDADE DE SAUDE DA FAMILIA DE LAGOINHA         301010030
# 3       UNIDADE DE SAUDE DA FAMILIA DE LAGOINHA         301010030
# 4       UNIDADE DE SAUDE DA FAMILIA DE LAGOINHA         301010030
#
#                                      NO_PROCEDIMENTO SEXO  COD_RACA RACACOR  \
# ...

# %%
import geopandas as geopd
import matplotlib.pyplot as plt

# %%
gdf = geopandas.GeoDataFrame(
    hosp, geometry=geopandas.points_from_xy(hosp.longitude, hosp.latitude))

# %%
gdf
# Out:
#          COD_MUNICIPIO NO_MUNICIPIO  COD_MUNICIPIO_RES NO_MUNICIPIO_RES  \
# 0               250010  AGUA BRANCA             240890         PARELHAS
# 1               250010  AGUA BRANCA             250010      AGUA BRANCA
# 2               250010  AGUA BRANCA             250010      AGUA BRANCA
# 3               250010  AGUA BRANCA             250010      AGUA BRANCA
# 4               250010  AGUA BRANCA             250010      AGUA BRANCA
# 5               250010  AGUA BRANCA             250010      AGUA BRANCA
# 6               250010  AGUA BRANCA             250010      AGUA BRANCA
# 7               250010  AGUA BRANCA             250010      AGUA BRANCA
# 8               250010  AGUA BRANCA             250010      AGUA BRANCA
# 9               250010  AGUA BRANCA             250010      AGUA BRANCA
# 10              250010  AGUA BRANCA             250010      AGUA BRANCA
# 11              250010  AGUA BRANCA             250010      AGUA BRANCA
# ...

# %%
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))

# We restrict to South America.
ax = world[world.continent == 'South America'].plot(
    color='white', edgecolor='black')

# We can now plot our ``GeoDataFrame``.
gdf.plot(ax=ax, color='red')

plt.show()

# %%
import folium


m = folium.Map(location=[-7.18810087, -36.52404785])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
1 - saber o q tem q estar no geojson OK
2 - criar um geodf OK
3 - converter o geodf pra geojson OK
4 - abrir o geojson no leaflet

# %%
gdf.to_file("hosp.geojson", driver='GeoJSON')

# %%
"https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png", {
                attribution:  `&copy; <a href="http://www.openstreetmap.org/copyright">OpenStreetMap</a>,
 Map tiles by &copy; <a href="https://carto.com/attribution">CARTO</a>`,
                maxZoom: 18
                }

# %%
var initialCoordinates = [-7.18810087, -36.52404785]
var initialZoomLevel = 13

var map = L.map('map').setView(initialCoordinates, initialZoomLevel)

L.tileLayer("https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png", {
            attribution:  `&copy; <a href="http://www.openstreetmap.org/copyright">OpenStreetMap</a>,
 Map tiles by &copy; <a href="https://carto.com/attribution">CARTO</a>`,maxZoom: 18}).addTo(map)

# %%
h = geopd.read_file("hosp.geojson")
h

# %%
var map = L.map('map').setView([37.8, -96], 4)

L.tileLayer("https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png", {
            attribution:  `&copy; <a href="http://www.openstreetmap.org/copyright">OpenStreetMap</a>,
 Map tiles by &copy; <a href="https://carto.com/attribution">CARTO</a>`,maxZoom: 18}).addTo(map)

L.geoJson(h).addTo(map);

# %%
var mapboxAccessToken = {your access token here};
var map = L.map('map').setView([37.8, -96], 4);

L.tileLayer('https://api.mapbox.com/styles/v1/{id}/tiles/{z}/{x}/{y}?access_token=' + mapboxAccessToken, {
    id: 'mapbox/light-v9',
    attribution: ...,
    tileSize: 512,
    zoomOffset: -1
}).addTo(map);

L.geoJson(statesData).addTo(map);

# %%
# Import libraries
import pandas as pd
import folium
 
# Load the shape of the zone (US states)
# Find the original file here: https://github.com/python-visualization/folium/tree/master/examples/data
# You have to download this file and set the directory where you saved it
state_geo = os.path.join('/Users/y.holtz/Desktop/', 'us-states.json')
 
# Load the unemployment value of each state
# Find the original file here: https://github.com/python-visualization/folium/tree/master/examples/data
state_unemployment = os.path.join('/Users/y.holtz/Desktop/', 'US_Unemployment_Oct2012.csv')
state_data = pd.read_csv(state_unemployment)
 
# Initialize the map:
m = folium.Map(location=[37, -102], zoom_start=5)
 
# Add the color for the chloropleth:
m.choropleth(
 geo_data=state_geo,
 name='choropleth',
 data=state_data,
 columns=['State', 'Unemployment'],
 key_on='feature.id',
 fill_color='YlGn',
 fill_opacity=0.7,
 line_opacity=0.2,
 legend_name='Unemployment Rate (%)'
)
folium.LayerControl().add_to(m)
